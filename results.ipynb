# %%
import pickle
from collections import namedtuple
import pandas as pd
import operator
import numpy as np
from IPython.display import display
from metrics import Results

# %%
metrics = 'normal_nll normal_nll_opt rmse auc_rmse auc_rmse_norm'.split()

def highlight_max(s):
    is_min = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_min]

with open('shallow_results.pkl', 'rb') as f:
    pr = pickle.load(f)
    
#with open('deep_results.pkl', 'rb') as f:
#    dr = pickle.load(f)

# %%
dr=[Results(datetime='2018-04-09 17:16:54.966323', dataset='make_friedman3', model='MLPNormal', shape=(30000, 4), normal_nll=(3.7254919794449464, 0.004230928971008379), normal_nll_opt=(3.725467188557807, 0.004229744810065016), rmse=(10.039021914533924, 0.042451484616102264), auc_rmse=(11.844083198042366, 0.11974808163785794), auc_rmse_norm=(1.179567300039282, 0.007750743204347696)),
Results(datetime='2018-04-09 17:18:02.720994', dataset='make_friedman3', model='MLPBaseline', shape=(30000, 4), normal_nll=(3.7259466584995926, 0.00437092123894489), normal_nll_opt=(3.725778429636759, 0.004351031159352522), rmse=(10.043465576713958, 0.04365465465707499), auc_rmse=(11.961885115213542, 0.057232100228208196), auc_rmse_norm=(1.190858770773635, 0.00542674709957977)),
Results(datetime='2018-04-09 17:19:27.568526', dataset='make_friedman3', model='MLPBayesianDropout', shape=(30000, 4), normal_nll=(1589.4254813624946, 58.946038931635755), normal_nll_opt=(1588.8393814703925, 59.16485468259782), rmse=(10.042488539199496, 0.044042145750808476), auc_rmse=(10.056346589115176, 0.06842187884410694), auc_rmse_norm=(1.0013152107095677, 0.0025815103362763292)),
Results(datetime='2018-04-09 17:20:03.457756', dataset='make_friedman2', model='MLPNormal', shape=(20000, 4), normal_nll=(7.35348812170964, 0.002925989280766077), normal_nll_opt=(7.353488119485975, 0.002925989945924055), rmse=(377.8538009629654, 1.1157133857463932), auc_rmse=(332.9425745861675, 3.7004877344096334), auc_rmse_norm=(0.8809791275360551, 0.007686408635068867)),
Results(datetime='2018-04-09 17:20:36.091294', dataset='make_friedman2', model='MLPBaseline', shape=(20000, 4), normal_nll=(4.788030479690052, 0.06032181677127762), normal_nll_opt=(4.7405920261998125, 0.07318476596314151), rmse=(29.162383341468693, 1.8034142569873144), auc_rmse=(34.73074263369456, 2.1814040364352114), auc_rmse_norm=(1.2136572642943466, 0.11255838618993377)),
Results(datetime='2018-04-09 17:21:23.221674', dataset='make_friedman2', model='MLPBayesianDropout', shape=(20000, 4), normal_nll=(4.349219034426133, 0.006463029475055557), normal_nll_opt=(4.3455080820914045, 0.0040359865093480204), rmse=(10.73535926234533, 0.4395852222407756), auc_rmse=(7.716261987922559, 0.3891875080526968), auc_rmse_norm=(0.7184080066528302, 0.01750485017914269)),
Results(datetime='2018-04-09 17:21:40.405737', dataset='make_friedman1', model='MLPNormal', shape=(10000, 10), normal_nll=(3.007765512289495, 0.005583339872264633), normal_nll_opt=(3.007532810626658, 0.005453946048629365), rmse=(4.89735608684142, 0.02697585196956413), auc_rmse=(4.947143945211197, 0.0493118993370027), auc_rmse_norm=(1.0104410948784497, 0.013446784393040378)),
Results(datetime='2018-04-09 17:21:56.122712', dataset='make_friedman1', model='MLPBaseline', shape=(10000, 10), normal_nll=(1.3107772959507318, 0.01477867897159166), normal_nll_opt=(1.3009690878337474, 0.015068906726679522), rmse=(0.8965749711737857, 0.013324712401532275), auc_rmse=(1.1002576363303473, 0.03363548266885038), auc_rmse_norm=(1.2283441800838282, 0.04554908272961667)),
Results(datetime='2018-04-09 17:22:21.594547', dataset='make_friedman1', model='MLPBayesianDropout', shape=(10000, 10), normal_nll=(0.7692749799301712, 0.008294554448781119), normal_nll_opt=(0.7678276072282444, 0.008408730860334683), rmse=(0.4969861234216183, 0.011096902147495393), auc_rmse=(0.38019100176361165, 0.00396070694532505), auc_rmse_norm=(0.7662387495154928, 0.015078713387669328)),
Results(datetime='2018-04-09 17:22:41.464697', dataset='make_regression', model='MLPNormal', shape=(10000, 100), normal_nll=(6.581695857368547, 0.01105465691108531), normal_nll_opt=(6.581695855417945, 0.011054657367979137), rmse=(174.54870240862442, 1.8859478441610356), auc_rmse=(174.7742994393365, 2.0299206513869077), auc_rmse_norm=(1.001429662403404, 0.007758552079630226)),
Results(datetime='2018-04-09 17:23:00.538747', dataset='make_regression', model='MLPBaseline', shape=(10000, 100), normal_nll=(4.9908394783970165, 0.060611980044886715), normal_nll_opt=(4.984465592275791, 0.061357440564359746), rmse=(35.68850616338951, 2.2511157732336167), auc_rmse=(41.6968829240926, 3.6678558746585295), auc_rmse_norm=(1.1610547696421758, 0.030329195588191336)),
Results(datetime='2018-04-09 17:23:30.259815', dataset='make_regression', model='MLPBayesianDropout', shape=(10000, 100), normal_nll=(4.357606425156883, 0.010219336932809287), normal_nll_opt=(4.356895402171507, 0.010142674681755086), rmse=(12.00635037551871, 0.4146219514744242), auc_rmse=(10.182583344541722, 0.18887980167713536), auc_rmse_norm=(0.8505847767561214, 0.020798180114616854)),
Results(datetime='2018-04-09 17:25:22.601142', dataset='yacht', model='MLPNormal', shape=(308, 6), normal_nll=(4.144535700929812, 0.027476046065370748), normal_nll_opt=(4.126850549989783, 0.02690769894894121), rmse=(14.948401155651442, 0.4184343417203885), auc_rmse=(13.760564640192825, 0.5035590377025619), auc_rmse_norm=(0.9253031478217537, 0.023655077868890394)),
Results(datetime='2018-04-09 17:28:00.378715', dataset='yacht', model='MLPBaseline', shape=(308, 6), normal_nll=(3.0407448688793215, 0.06889291818413305), normal_nll_opt=(2.8063595352582804, 0.04830451196590436), rmse=(4.318935390126231, 0.16957055851466027), auc_rmse=(4.334706399346624, 0.2344995851009649), auc_rmse_norm=(1.0164097881607836, 0.04827093925456332)),
Results(datetime='2018-04-09 17:31:22.852789', dataset='yacht', model='MLPBayesianDropout', shape=(308, 6), normal_nll=(3.98059362523403, 0.33664764086958215), normal_nll_opt=(2.817033212158729, 0.08939402387141666), rmse=(4.211011419087971, 0.1954148704392802), auc_rmse=(2.4331961335874817, 0.09846346946488926), auc_rmse_norm=(0.6049344557730542, 0.031172998670795978)),
Results(datetime='2018-04-09 17:35:47.815397', dataset='wine', model='MLPNormal', shape=(1599, 11), normal_nll=(1.20674966311519, 0.010612627613429635), normal_nll_opt=(1.2016111544619092, 0.010521754619340592), rmse=(0.8062356096300478, 0.008824353977667692), auc_rmse=(0.7833952608662819, 0.012964583904043493), auc_rmse_norm=(0.9708583075330848, 0.010210210809235818)),
Results(datetime='2018-04-09 17:41:03.022077', dataset='wine', model='MLPBaseline', shape=(1599, 11), normal_nll=(0.9663709213982022, 0.012357067276135461), normal_nll_opt=(0.9487267720861057, 0.010043147052805318), rmse=(0.6293196691524174, 0.006428624849986578), auc_rmse=(0.7531974569121912, 0.015159614256891463), auc_rmse_norm=(1.1888595702653115, 0.017239809560637944)),
Results(datetime='2018-04-09 17:47:20.495256', dataset='wine', model='MLPBayesianDropout', shape=(1599, 11), normal_nll=(13.418674007755405, 0.37787307140697024), normal_nll_opt=(13.274919574886667, 0.3671045453040069), rmse=(0.6268743351649891, 0.0071288614995185275), auc_rmse=(0.5759731689704765, 0.006910840826414912), auc_rmse_norm=(0.9195301452884612, 0.0066373272420816466)),
Results(datetime='2018-04-09 17:53:05.432266', dataset='protein', model='MLPNormal', shape=(45730, 9), normal_nll=(3.230392938481776, 0.004932300769985245), normal_nll_opt=(3.230232300924806, 0.0049143165506289445), rmse=(6.118527027651274, 0.030019499888634227), auc_rmse=(5.7560581730444405, 0.11592564977235584), auc_rmse_norm=(0.9409093275920725, 0.022188484671658917)),
Results(datetime='2018-04-09 17:58:46.554415', dataset='protein', model='MLPBaseline', shape=(45730, 9), normal_nll=(2.8524867978422104, 0.00479627019372427), normal_nll_opt=(2.8517441415439237, 0.004698347728946589), rmse=(4.191831613971945, 0.01925164859323557), auc_rmse=(4.437358760137872, 0.05969620167592671), auc_rmse_norm=(1.0584026243461768, 0.009350806422709019)),
Results(datetime='2018-04-09 18:06:59.967144', dataset='protein', model='MLPBayesianDropout', shape=(45730, 9), normal_nll=(9.880812502196564, 0.17315004006959858), normal_nll_opt=(9.879366898374634, 0.17212956477625482), rmse=(4.192419616498328, 0.009771067946672254), auc_rmse=(3.8631002045955323, 0.06186587987658387), auc_rmse_norm=(0.9214222288220686, 0.013164427312971983)),
Results(datetime='2018-04-09 18:15:53.372270', dataset='power', model='MLPNormal', shape=(9568, 4), normal_nll=(4.256191141964722, 0.0025548383865548596), normal_nll_opt=(4.255609174292663, 0.0025483745432835284), rmse=(17.065678478449037, 0.043701394827609624), auc_rmse=(16.811391038438387, 0.15634753612516547), auc_rmse_norm=(0.9853263396913222, 0.009130098639977977)),
Results(datetime='2018-04-09 18:25:55.730361', dataset='power', model='MLPBaseline', shape=(9568, 4), normal_nll=(2.955425577228431, 0.007949633185922298), normal_nll_opt=(2.9499194163801876, 0.007727197711686545), rmse=(4.6459572183851305, 0.03662909925464524), auc_rmse=(5.8323538430757385, 0.08365259525209001), auc_rmse_norm=(1.2520111763198414, 0.012490135176090097)),
Results(datetime='2018-04-09 18:39:43.648002', dataset='power', model='MLPBayesianDropout', shape=(9568, 4), normal_nll=(5.729814133664674, 0.04362954341420751), normal_nll_opt=(5.712575107390731, 0.044577233954324516), rmse=(4.125267475486847, 0.025739434881515828), auc_rmse=(3.9170691124181047, 0.021797612972469158), auc_rmse_norm=(0.9505037762776933, 0.005961952902256966)),
Results(datetime='2018-04-09 18:52:22.048283', dataset='naval', model='MLPNormal', shape=(11934, 16), normal_nll=(-2.799556462135658, 0.001781753449386951), normal_nll_opt=(-2.7998335964862173, 0.0017770324003353627), rmse=(0.014719466832099532, 2.6189659028739183e-05), auc_rmse=(0.015874592781142977, 0.00010210066546899152), auc_rmse_norm=(1.078463475138821, 0.007106472960844023)),
Results(datetime='2018-04-09 19:06:29.506455', dataset='naval', model='MLPBaseline', shape=(11934, 16), normal_nll=(-4.777986846036184, 0.024238436107884214), normal_nll_opt=(-4.800642717601833, 0.022762050268869606), rmse=(0.002056850068220498, 5.5265490345807334e-05), auc_rmse=(0.0024712809909802624, 0.00010150267252323669), auc_rmse_norm=(1.1907852489587474, 0.022054558855128147)),
Results(datetime='2018-04-09 19:26:48.124976', dataset='naval', model='MLPBayesianDropout', shape=(11934, 16), normal_nll=(-4.63543744591385, 0.011548708978525446), normal_nll_opt=(-4.645525134183392, 0.011335178519677259), rmse=(0.002241688258798469, 3.877854266894482e-05), auc_rmse=(0.0019515821895090628, 4.350121828291039e-05), auc_rmse_norm=(0.8691042874852851, 0.007925160351960406)),
Results(datetime='2018-04-09 19:41:18.947093', dataset='kin8nm', model='MLPNormal', shape=(8192, 8), normal_nll=(0.08576876573646788, 0.003113512594409141), normal_nll_opt=(0.08518979482438511, 0.0031356606722089835), rmse=(0.2635689951264999, 0.0008219907906973139), auc_rmse=(0.2661489657165658, 0.002085061807603237), auc_rmse_norm=(1.0097224644047385, 0.0066567315790873275)),
Results(datetime='2018-04-09 19:57:16.308634', dataset='kin8nm', model='MLPBaseline', shape=(8192, 8), normal_nll=(-1.0413696423374477, 0.005635097435413466), normal_nll_opt=(-1.0489307695515535, 0.005201843532258528), rmse=(0.08500842815998136, 0.00042721262209782784), auc_rmse=(0.10308936652211217, 0.0009281512597562881), auc_rmse_norm=(1.211153207598049, 0.008459102905198817)),
Results(datetime='2018-04-09 20:18:48.822762', dataset='kin8nm', model='MLPBayesianDropout', shape=(8192, 8), normal_nll=(-0.7912142617769391, 0.012169936516972698), normal_nll_opt=(-0.7996654117318417, 0.012054579856623969), rmse=(0.0847353735468127, 0.00047700914862162935), auc_rmse=(0.0720899165895098, 0.00033923374435007326), auc_rmse_norm=(0.851457149453509, 0.004237603267383908)),
Results(datetime='2018-04-09 20:33:17.279496', dataset='energy', model='MLPNormal', shape=(768, 8), normal_nll=(3.7320446954301945, 0.007655671571396631), normal_nll_opt=(3.7239289442275902, 0.00777436704751303), rmse=(10.086945762837244, 0.0763935093767316), auc_rmse=(10.129779653377382, 0.116650516686613), auc_rmse_norm=(1.005416958453983, 0.010543649459412168)),
Results(datetime='2018-04-09 20:48:40.763481', dataset='energy', model='MLPBaseline', shape=(768, 8), normal_nll=(2.528228284038592, 0.01254807922407241), normal_nll_opt=(2.5092010717797293, 0.011328553399417234), rmse=(3.0135822845485163, 0.03376421971636312), auc_rmse=(3.1124889115754537, 0.061875334342789405), auc_rmse_norm=(1.030230369936477, 0.02161376684709084)),
Results(datetime='2018-04-09 21:05:36.959651', dataset='energy', model='MLPBayesianDropout', shape=(768, 8), normal_nll=(2.9093701780012404, 0.0633949541054356), normal_nll_opt=(2.872868274554558, 0.06043495580392014), rmse=(2.7145844894106657, 0.049124372453054226), auc_rmse=(2.5744516192317617, 0.06283991258671995), auc_rmse_norm=(0.9496613259578046, 0.01673260544614411))]

# %%
df = pd.DataFrame.from_records(pr + dr, columns=Results._fields)

# %%
for m in metrics:
    print(m.upper())
    pdf = df.pivot(index='dataset', columns='model', values=m)
    def getter(cell):
        try:
            return cell[0]
        except:
            return np.nan
    display(pdf.applymap(getter).style.apply(highlight_max, axis=1))
# Out:
# NORMAL_NLL
# <style  type="text/css" >
#     #T_ca347a9c_3c3c_11e8_942f_0242ac110002row0_col0 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row1_col9 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row2_col9 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row3_col3 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row4_col4 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row5_col7 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row6_col2 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row7_col0 {
#             background-color:  yellow;
#         }    #T_ca347a9c_3c3c_11e8_942f_0242ac110002row8_col3 {
#             background-color:  yellow;
# ...
